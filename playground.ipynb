# %%
import numpy as np

# %%
path = "s12_temp_folder"

# %%
data = np.load(path+"/S2_DATA.npy")

# %%
print(data)
# Out:
# [[[0.10616845 0.09519573 0.09252669 ... 0.1227758  0.12959668 0.14501779]
#   [0.10409253 0.10468565 0.10438909 ... 0.12188612 0.12633452 0.13819692]
#   [0.10972716 0.10498221 0.09875445 ... 0.17289442 0.15776987 0.15361803]
#   ...
#   [0.08985765 0.0732503  0.08303677 ... 0.15688019 0.11032028 0.10794781]
#   [0.06079478 0.05219454 0.06198102 ... 0.11032028 0.10112693 0.1168446 ]
#   [0.11654804 0.11269276 0.12099644 ... 0.10972716 0.12663108 0.136121  ]]
#
#  [[0.14620403 0.13582444 0.1316726  ... 0.16132859 0.15599051 0.16429419]
#   [0.14264531 0.14234875 0.13938316 ... 0.15243179 0.14768683 0.15836299]
#   [0.13819692 0.14323843 0.14145907 ... 0.18060498 0.16963227 0.17052195]
#   ...
#   [0.12900356 0.11803084 0.12307236 ... 0.18623962 0.15450771 0.15361803]
#   [0.10349941 0.09786477 0.10765125 ... 0.16992883 0.14590747 0.15065243]
#   [0.1376038  0.13790036 0.14472123 ... 0.16014235 0.15628707 0.15599051]]
#
# ...

# %%
print(data.shape)
print(data.dtype)
# Out:
# (4, 256, 256)
# float64

# %%
from matplotlib import pyplot as plt

image = data[0,:,:]
plt.imshow(image)

# %%
image2 = data[1,:,:]
plt.imshow(image2)

# %%
image3 = data[2,:,:]
plt.imshow(image3)

# %%
image4 = data[3,:,:]
plt.imshow(image4)

# %%
nimage=3;

final = image/nimage + image2/nimage + image3/nimage

# %%
plt.imshow(final)

# %%
# rgb = np.zeros(image.shape[0], image.shape[1], 3)
rgb = np.dstack([image, image2, image3])

# %%
plt.imshow(rgb)

# %%
new1 = np.dstack([image2, image3, image4])
plt.imshow(new1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
new2 = np.dstack([image, image2, image3, image4])
plt.imshow(new2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
